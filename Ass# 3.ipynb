# %%
##Task1
print ("Calculator")
val1= int(input("Enter first value : "))
val2= int(input ("Enter second value : "))
operator = input("Enter Operator : ")

if operator == '+':
    val= val1 + val2
    print ("Answer =", val)
elif operator == '-':
    val = val1 - val2
    print ("Answer =", val)
elif operator == '*':
    val= val1 * val2
    print("Answer =",val)
elif operator == '/':
    val = val1 / val2
    print ("Answer =", val)
elif operator == '**':
    val= val1 ** val2
    print ("Answer = ",val)
else:
    print ("Enter Correct Operator")
# Out:
# Calculator
# Enter first value : 58
# Enter second value : 4
# Enter Operator : /
# Answer = 14.5

# %%
##Task 2
list = ["Ali", 56, "Ahmed"]
for item in list:
    if item.list():
     print ("Numerical value is present",x)
    else:
        print ("Numerical value is not present")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-800463dc1857> in <module>
#       2 list = ["Ali", 56, "Ahmed"]
#       3 for item in list:
# ----> 4     if item.list():
#       5      print ("Numerical value is present")
#       6     else:
#
# AttributeError: 'str' object has no attribute 'list'

# %%
##Task3
dict = {"Name" : "Mubashir",
    "Subject" : "OOP",}
dict["language"]= "Python"
print(dict)
# Out:
# {'Name': 'Mubashir', 'Subject': 'OOP', 'language': 'Python'}

# %%
##Task4
dict={'A':113,'B':567,'C':200}
print("Sum of all Numeric items = ",sum(dict.values()))
# Out:
# Sum of all Numeric items =  880

# %%
##Task5
arr=[4,9,7,14,45,7,2,9,3,4]
arr.sort()
for i in range (len(arr)-1):
    if arr[i] == arr[i+1]:
        print (arr[i])
# Out:
# 4
# 7
# 9

# %%
##Task6
dic = {'A':299, 'B':399, 'C':499}
key= input("Enter Key :")
if key in dic.keys():
    print("Key exists")
else:
    print("Key doesn't exists")
# Out:
# Enter Key :B
# Key exists
